# %%
import plotly.express as px
import numpy as np

# %%
x = np.random.random(20)
y = x * x

fig = px.scatter(
    x = x,
    y = y
)

fig.show(renderer = 'png')

# %%
print("This is nice!")
# Out:
# This is nice!
